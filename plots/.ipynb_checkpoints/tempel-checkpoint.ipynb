# %%
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
import random
from collections import Counter
import numpy as np
from itertools import cycle, islice

# %% [markdown]
# # Tempel

# %% [markdown]
# **tempel_limpio.dat**: DR12 SDSS sample of galaxies
#
#     - galID   :ID galaxia (SDSS)
#     - ra[rad] :Asención recta
#     - dec[rad]:Declinacion
#     - zCMB   :Galaxy redshift corrected to the CMB rest-frame.
#     - rextAB :r-band observer-frame model apparent magnitud corrected for galactic extinction in AB system.
#     - gextAB :g-band observer-frame model apparent magnitud corrected for galactic extinction in AB system.
#     - rabs :r-band k-corrected absolute magnitude.
#     - gabs :g-band k-corrected absolute magnitude.
#     - Menv :absolute magntude "r", Menv= mlim - 25 -5*log(ld) -kr, (mlim=17.77) .

# %%
path_gal_gru = '../../catalogos/tempel_limpio.dat'


df = pd.read_table(path_gal_gru, sep="\s+", names=['galID', 'ra_rad', 'dec_rad', 'zCMB', 'rextAB', 'gextAB'])
#, 'rabs', 'gabs', 'Menv'
display(df.shape)
display(df.head(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-94e48a21d0c7> in <module>
#       2
#       3
# ----> 4 df = pd.read_table(path_gal_gru, sep="\s+", names=['galID', 'ra_rad', 'dec_rad', 'zCMB', 'rextAB', 'gextAB'])
#       5 #, 'rabs', 'gabs', 'Menv'
#       6 display(df.shape)
#
# NameError: name 'pd' is not defined

# %%
df.describe()
# Out:
#               galID         ra_rad        dec_rad           zCMB  \
# count  5.575590e+05  557559.000000  557559.000000  557559.000000
# mean   1.237662e+18       3.243881       0.472808       0.098996
# std    5.656351e+12       0.660586       0.311077       0.044951
# min    1.237649e+18       1.915685      -0.065414       0.000146
# 25%    1.237658e+18       2.713526       0.212609       0.065501
# 50%    1.237662e+18       3.237212       0.452644       0.095587
# 75%    1.237666e+18       3.799847       0.707482       0.132439
# max    1.237675e+18       4.570260       1.226423       0.199999
#
#               rextAB         gextAB
# count  557559.000000  557559.000000
# mean       16.841969      17.538159
# std         0.795484      32.870037
# min         9.446938   -9999.215704
# 25%        16.508394      17.265486
# 50%        17.071351      17.846251
# 75%        17.416182      18.237686
# max        17.767403      20.485298

# %%
import math
pi = math.pi
plt.scatter(df.ra_rad*180/pi, df.dec_rad*180/pi, s= 0.0001)
plt.xlabel('ra')
plt.ylabel('dec')
# Out:
# Text(0, 0.5, 'dec')

# %%
plt.hist(df.zCMB, 200)
# Out:
# (array([  14.,   55.,  195.,  318.,  461.,  535.,  596.,  540.,  468.,
#          391.,  363.,  490.,  393.,  493.,  657.,  713.,  804.,  706.,
#          740.,  773.,  898., 1503., 2053., 2454., 2419., 2209., 2172.,
#         2214., 2368., 2788., 2777., 2960., 2719., 2895., 2943., 2867.,
#         2664., 2564., 2385., 2390., 2432., 2597., 2496., 2632., 2659.,
#         3126., 3381., 3284., 2856., 2958., 3103., 3267., 3492., 3424.,
#         3379., 3331., 2967., 2833., 2732., 2943., 3335., 3731., 3897.,
#         4262., 4568., 4307., 4209., 4171., 4148., 4227., 4531., 4823.,
#         5216., 5068., 5088., 5068., 5314., 4958., 5084., 5072., 4901.,
#         5193., 5276., 5071., 4961., 4991., 4624., 4649., 4433., 4275.,
#         3938., 3739., 3742., 4036., 3960., 4088., 3955., 4024., 3694.,
#         3701., 3719., 3779., 3858., 3931., 3962., 3757., 3771., 3968.,
#         3919., 3830., 3608., 3969., 4072., 4231., 4214., 4146., 4202.,
#         4049., 3863., 3891., 3661., 3451., 3338., 3408., 3495., 3367.,
#         3653., 3650., 3411., 3463., 3424., 3526., 3629., 3681., 3575.,
#         3694., 3556., 3312., 3244., 3175., 3025., 3019., 2986., 2883.,
#         2710., 2677., 2730., 2517., 2541., 2773., 2755., 2733., 2518.,
#         2411., 2478., 2255., 2272., 2229., 2174., 2093., 2116., 2027.,
#         1997., 2060., 2055., 2001., 2049., 1987., 1974., 1825., 1774.,
#         1731., 1649., 1739., 1652., 1657., 1563., 1667., 1580., 1562.,
#         1658., 1528., 1538., 1465., 1337., 1314., 1265., 1259., 1172.,
#         1247., 1214., 1144., 1149., 1061., 1154., 1029.,  997.,  994.,
#         1021.,  950.]),
#  array([1.46481000e-04, 1.14574467e-03, 2.14500834e-03, 3.14427201e-03,
#         4.14353568e-03, 5.14279935e-03, 6.14206302e-03, 7.14132669e-03,
#         8.14059036e-03, 9.13985403e-03, 1.01391177e-02, 1.11383814e-02,
#         1.21376450e-02, 1.31369087e-02, 1.41361724e-02, 1.51354360e-02,
#         1.61346997e-02, 1.71339634e-02, 1.81332271e-02, 1.91324907e-02,
#         2.01317544e-02, 2.11310181e-02, 2.21302817e-02, 2.31295454e-02,
#         2.41288091e-02, 2.51280727e-02, 2.61273364e-02, 2.71266001e-02,
#         2.81258638e-02, 2.91251274e-02, 3.01243911e-02, 3.11236548e-02,
#         3.21229184e-02, 3.31221821e-02, 3.41214458e-02, 3.51207094e-02,
#         3.61199731e-02, 3.71192368e-02, 3.81185005e-02, 3.91177641e-02,
#         4.01170278e-02, 4.11162915e-02, 4.21155551e-02, 4.31148188e-02,
#         4.41140825e-02, 4.51133461e-02, 4.61126098e-02, 4.71118735e-02,
#         4.81111372e-02, 4.91104008e-02, 5.01096645e-02, 5.11089282e-02,
#         5.21081918e-02, 5.31074555e-02, 5.41067192e-02, 5.51059828e-02,
#         5.61052465e-02, 5.71045102e-02, 5.81037739e-02, 5.91030375e-02,
#         6.01023012e-02, 6.11015649e-02, 6.21008285e-02, 6.31000922e-02,
#         6.40993559e-02, 6.50986196e-02, 6.60978832e-02, 6.70971469e-02,
#         6.80964106e-02, 6.90956742e-02, 7.00949379e-02, 7.10942016e-02,
#         7.20934652e-02, 7.30927289e-02, 7.40919926e-02, 7.50912563e-02,
#         7.60905199e-02, 7.70897836e-02, 7.80890473e-02, 7.90883109e-02,
#         8.00875746e-02, 8.10868383e-02, 8.20861019e-02, 8.30853656e-02,
#         8.40846293e-02, 8.50838930e-02, 8.60831566e-02, 8.70824203e-02,
#         8.80816840e-02, 8.90809476e-02, 9.00802113e-02, 9.10794750e-02,
#         9.20787386e-02, 9.30780023e-02, 9.40772660e-02, 9.50765297e-02,
#         9.60757933e-02, 9.70750570e-02, 9.80743207e-02, 9.90735843e-02,
#         1.00072848e-01, 1.01072112e-01, 1.02071375e-01, 1.03070639e-01,
#         1.04069903e-01, 1.05069166e-01, 1.06068430e-01, 1.07067694e-01,
#         1.08066957e-01, 1.09066221e-01, 1.10065485e-01, 1.11064748e-01,
#         1.12064012e-01, 1.13063276e-01, 1.14062539e-01, 1.15061803e-01,
#         1.16061067e-01, 1.17060330e-01, 1.18059594e-01, 1.19058858e-01,
#         1.20058121e-01, 1.21057385e-01, 1.22056649e-01, 1.23055912e-01,
#         1.24055176e-01, 1.25054440e-01, 1.26053703e-01, 1.27052967e-01,
#         1.28052231e-01, 1.29051494e-01, 1.30050758e-01, 1.31050022e-01,
#         1.32049285e-01, 1.33048549e-01, 1.34047813e-01, 1.35047076e-01,
#         1.36046340e-01, 1.37045604e-01, 1.38044867e-01, 1.39044131e-01,
#         1.40043395e-01, 1.41042658e-01, 1.42041922e-01, 1.43041186e-01,
#         1.44040449e-01, 1.45039713e-01, 1.46038977e-01, 1.47038240e-01,
#         1.48037504e-01, 1.49036768e-01, 1.50036031e-01, 1.51035295e-01,
#         1.52034559e-01, 1.53033823e-01, 1.54033086e-01, 1.55032350e-01,
#         1.56031614e-01, 1.57030877e-01, 1.58030141e-01, 1.59029405e-01,
#         1.60028668e-01, 1.61027932e-01, 1.62027196e-01, 1.63026459e-01,
#         1.64025723e-01, 1.65024987e-01, 1.66024250e-01, 1.67023514e-01,
#         1.68022778e-01, 1.69022041e-01, 1.70021305e-01, 1.71020569e-01,
#         1.72019832e-01, 1.73019096e-01, 1.74018360e-01, 1.75017623e-01,
#         1.76016887e-01, 1.77016151e-01, 1.78015414e-01, 1.79014678e-01,
#         1.80013942e-01, 1.81013205e-01, 1.82012469e-01, 1.83011733e-01,
#         1.84010996e-01, 1.85010260e-01, 1.86009524e-01, 1.87008787e-01,
#         1.88008051e-01, 1.89007315e-01, 1.90006578e-01, 1.91005842e-01,
#         1.92005106e-01, 1.93004369e-01, 1.94003633e-01, 1.95002897e-01,
#         1.96002160e-01, 1.97001424e-01, 1.98000688e-01, 1.98999951e-01,
#         1.99999215e-01]),
#  <a list of 200 Patch objects>)

# %%
plt.scatter(df.zCMB, df.rextAB, s= 0.0001)
plt.xlabel('z')
plt.ylabel(r'$mag_r$')
plt.xlim(0,0.2)
plt.ylim(12,18)
plt.show()

# %%
df1 = df[df['gextAB'] > 17]
display(df1.shape)
df1.head(2)
# Out:
# (457212, 6)
#                  galID    ra_rad   dec_rad      zCMB     rextAB     gextAB
# 1  1237667108498440277  2.129668  0.285548  0.101815  17.194962  18.246586
# 2  1237667142858899877  2.129055  0.286631  0.102300  17.104173  18.041415

# %%
plt.hist(df1.gextAB, histtype='step', label='g')
plt.hist(df1.rextAB, histtype='step', label='r')
plt.ylabel('count')
plt.xlabel(r'$mag_{aparente}$')
plt.title('tempel_limpio.dat')
plt.legend()
plt.show()

# %% [markdown]
# ## Color aparente g-r

# %%
g_r = df1.gextAB - df1.rextAB
plt.hist(g_r, 500, histtype='step', density=True)
plt.xlim(-0.1, 1.4)
plt.xlabel(r'$g-r$')
plt.show()

# %% [markdown]
# # **Correcion K**

# %%
dfk = pd.read_table("tempel_kcorr.dat", sep="\s+", names=['z', 'mr', 'kr', 'mg', 'kg'])
#dfk = pd.read_table("tempel_kcorr.dat", sep="\s+", names=['z', 'kr'])

# %%
dfk.head(3)
# Out:
#           z         mr        kr         mg        kg
# 0  0.101670 -22.276813  0.098686 -21.434483  0.278915
# 1  0.101815 -19.659205  0.100937 -18.791185  0.284542
# 2  0.102300 -19.750313  0.089993 -18.979822  0.256742

# %%
display(min(dfk.z), max(dfk.z))
display(min(dfk.kr), max(dfk.kr))
display(min(dfk.mr), max(dfk.mr))
display(min(dfk.mg), max(dfk.mg))
# Out:
# 0.00014648100500000002
# 0.199999213
# -3.15560985
# 332892701000.0
# -332892701000.0
# -4.93149757
# -908355437000.0
# -3.53374171

# %%
indx = np.where((dfk.mr > -27.) & (dfk.mr < -15.) & (dfk.mg > -27.) & (dfk.mg < -15.) & (dfk.kr > -1.5) & (dfk.kg > -1.5))
np.shape(indx)
# Out:
# (1, 554244)

# %%
zz=dfk.z.values[indx]
r=dfk.mr.values[indx]
g=dfk.mg.values[indx]
kkr=dfk.kr.values[indx]
kkg=dfk.kg.values[indx]

display(min(zz), max(zz))
display(min(r), max(r))
display(min(g), max(g))
display(min(kkr), max(kkr))
display(min(kkg), max(kkg))
# Out:
# 0.000884581998
# 0.199999213
# -24.0188217
# -15.0554066
# -25.050826999999998
# -15.0009041
# -0.73712033
# 0.7639860509999999
# -1.49980819
# 2.22657728

# %%
display(kkr)
display(zz)
# Out:
# array([0.09868575, 0.10093706, 0.08999259, ..., 0.14366303, 0.02931623,
#        0.02586553])
# array([0.10166964, 0.10181501, 0.10229951, ..., 0.1342077 , 0.03032968,
#        0.02527587])

# %%
kkr.shape
# Out:
# (554244,)

# %%
plt.plot(zz,kkr, 'g.',linestyle='None', markersize=0.10)
plt.show()

# %%
plt.plot(zz,kkr/zz, 'g.',linestyle='None', markersize=0.1)
plt.show()

# %%
ic1 = np.where(((g-r) > 0.0) & ((g-r)<= 0.4))
ic2 = np.where(((g-r) > 0.4) & ((g-r)<= 0.6))
ic3 = np.where(((g-r) > 0.6) & ((g-r)<= 0.7))
ic4 = np.where(((g-r) > 0.7) & ((g-r)<= 0.8))
ic5 = np.where(((g-r) > 0.8) & ((g-r)<= 1.0))
np.shape(ic1),np.shape(ic2),np.shape(ic3),np.shape(ic4),np.shape(ic5)
# Out:
# ((1, 31834), (1, 128327), (1, 94285), (1, 196013), (1, 102904))

# %%
fig, ax = plt.subplots()
ax.plot(zz[ic1], kkr[ic1], 'b.',linestyle='None', markersize=0.1,label='(0.0,0.4]')
ax.plot(zz[ic2], kkr[ic2], 'c.',linestyle='None', markersize=0.1,label='(0.4,0.6]')
ax.plot(zz[ic3], kkr[ic3], 'g.',linestyle='None', markersize=0.1,label='(0.6,0.7]')
ax.plot(zz[ic4], kkr[ic4], 'y.',linestyle='None', markersize=0.1,label='(0.7,0.8]')
ax.plot(zz[ic5], kkr[ic5], 'r.',linestyle='None', markersize=0.1,label='(0.8,1.0]')

ax.set_xlim(0,0.2)
ax.set_ylim(-0.1,0.2)

ax.set_xlabel('Redshift')
ax.set_ylabel('Kr')
ax.legend(loc='upper left')
plt.show()
#fig.savefig('test_kcorr.pdf')

# %%
fig, ax = plt.subplots()
ax.plot(zz[ic1], kkg[ic1], 'b.',linestyle='None', markersize=0.1,label='(0.0,0.4]')
ax.plot(zz[ic2], kkg[ic2], 'c.',linestyle='None', markersize=0.1,label='(0.4,0.6]')
ax.plot(zz[ic3], kkg[ic3], 'g.',linestyle='None', markersize=0.1,label='(0.6,0.7]')
ax.plot(zz[ic4], kkg[ic4], 'y.',linestyle='None', markersize=0.1,label='(0.7,0.8]')
ax.plot(zz[ic5], kkg[ic5], 'r.',linestyle='None', markersize=0.1,label='(0.8,1.0]')

ax.set_xlim(0,0.2)
ax.set_ylim(-0.1,0.5)

ax.set_xlabel('Redshift')
ax.set_ylabel('Kg')
ax.legend(loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(zz[ic1], kkr[ic1]/zz[ic1], 'b.',linestyle='None', markersize=0.1,label='(0.0,0.4]')
ax.plot(zz[ic2], kkr[ic2]/zz[ic2], 'c.',linestyle='None', markersize=0.1,label='(0.4,0.6]')
ax.plot(zz[ic3], kkr[ic3]/zz[ic3], 'g.',linestyle='None', markersize=0.1,label='(0.6,0.7]')
ax.plot(zz[ic4], kkr[ic4]/zz[ic4], 'y.',linestyle='None', markersize=0.1,label='(0.7,0.8]')
ax.plot(zz[ic5], kkr[ic5]/zz[ic5], 'r.',linestyle='None', markersize=0.1,label='(0.8,1.0]')
ax.set_xlim(0,0.2)
ax.set_ylim(-0.7,1.5)
ax.set_xlabel('Redshift')
ax.set_ylabel('Kr/Redshift')

plt.legend()
ax.legend(loc='lower left')
plt.show()

# %% [markdown]
# # Color g-r (Mabs)

# %%
fig, ax = plt.subplots()
#ax.plot(r[ic1], g[ic1] - r[ic1], 'b.',linestyle='None', markersize=0.1,label='(0.0,0.4]')
#ax.plot(r[ic2], g[ic2] - r[ic2], 'c.',linestyle='None', markersize=0.1,label='(0.4,0.6]')
#ax.plot(r[ic3], g[ic3] - r[ic3], 'g.',linestyle='None', markersize=0.1,label='(0.6,0.7]')
#ax.plot(r[ic4], g[ic4] - r[ic4], 'y.',linestyle='None', markersize=0.1,label='(0.7,0.8]')
#ax.plot(r[ic5], g[ic5] - r[ic5], 'r.',linestyle='None', markersize=0.1,label='(0.8,1.0]')
ax.plot(r, g - r, 'b.',linestyle='None', markersize=0.01,label='nada')
ax.set_ylim(0.2,1.1)
ax.set_xlim(-23,-17)
ax.set_xlabel('Mr')
ax.set_ylabel('g-r')

ax.legend(loc='lower left')
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(g - r, 200)
ax.set_xlim(0,1.1)
plt.show()

# %%
np.shape(g - r),min(g-r),max(g-r)
# Out:
# ((554244,), -2.054002699999998, 3.1161861)

# %%
color=g - r
c1=np.where((r >= -23.) & (r < -22.))

# %%
iz = np.where((zz>0.0) & (zz<0.05))
fig, ax = plt.subplots()
ax.hist(g[iz] - r[iz], 200)
ax.set_xlim(0,1.1)
plt.show()

# %%
iz = np.where((zz>0.05) & (zz<0.1))
fig, ax = plt.subplots()
ax.hist(g[iz] - r[iz], 200)
ax.set_xlim(0,1.1)
plt.show()

# %% [markdown]
# ## GaussianMixture

# %%
xx=np.arange(-22.5,-17,0.4)
xx

# %%
from sklearn.mixture import GaussianMixture
import scipy.stats as stats
for i in range(2,3):
    icol = np.where((r >= xx[i]) & (r < xx[i+1])) 
    col = color[icol]
    display(np.shape(col)) 
    col = col.reshape(-1, 1)
    display(np.shape(col))    
    gm = GaussianMixture(n_components=2, random_state=0).fit(col)
    display(gm.means_)
    weights = gm.weights_
    means = gm.means_
    covars = gm.covariances_
    plt.hist(col, bins=100, histtype='bar', density=True, ec='grey', alpha=0.5)
    #plt.plot(col,weights[0]*stats.norm.pdf(col,means[0],np.sqrt(covars[0])))
    #plt.rcParams['agg.path.chunksize'] = 10000
    x_range = np.linspace(0, 3, 1000)
    pdf = np.exp(gm.score_samples(x_range.reshape(-1, 1)))
    responsibilities = gm.predict_proba(x_range.reshape(-1, 1))
    pdf_individual = responsibilities * pdf[:, np.newaxis]
    plt.plot(x_range, pdf, '-k', label='Mixture')
    plt.plot(x_range, pdf_individual, '--r', label='Components')
    plt.legend()
    display(gm.score_samples)
    plt.show()

# %% [markdown]
# ## Clean data

# %%
display('Valores faltantes',dfk.notnull().all().to_frame())
display('Estadísticos del dataset',dfk.z.describe())
display('Estadísticos del dataset',dfk.mr.describe())
display('Estadísticos del dataset',dfk.kr.describe())
display('Estadísticos del dataset',dfk.mg.describe())
display('Estadísticos del dataset',dfk.kg.describe())

# %%
#Valores duplicados
dfk[dfk.duplicated()].sort_values(['z'])

# %%
#dfk['mr'] = dfk['mr'].astype(float, errors = 'raise')

# %%
#dfk[dfk.kg.str.contains('*************')]

# %%
#df_raro = dfk[dfk.kr == '*************']

# %%
#df_raro

# %%
#dfk.kr.hist()

# %%
dfk.select_dtypes(['float']).columns
dfk.select_dtypes(['string']).columns
dfk.select_dtypes(['object']).columns

# %%
#dfk.iloc[dfk.z.dtypes == np.float64, :]

# %%
is_NaN = dfk.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = dfk[row_has_NaN]
print(rows_with_NaN)

# %%
dfna= dfk[dfk['mr'].isna()]

# %%
dfna.shape

# %%
#dfk2=dfk.fillna(-999)
#df. dropna()

# %%
cdf = dfk[~dfk.applymap(np.isreal).all(1)]

# %%
display(cdf.min())
display(cdf.max())

# %%
#cdf.mr.hist()

# %%
cdf.shape

# %%
bfk = dfk[dfk.applymap(np.isreal).all(1)]

# %%
bfk.head(10)

# %%
bfk.shape

# %%
bfk.mr.dtype

# %%
bfk['mr'] = bfk['mr'].astype(float, errors = 'raise')

# %%
bfk['mr'].dtype
